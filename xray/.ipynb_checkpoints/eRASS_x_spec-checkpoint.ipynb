# %% [markdown]
# # Figure 5

# %%
import numpy as np
from astropy.table import Table
import astropy.constants as const
import astropy.io.ascii as asci

import astropy.constants as const

import matplotlib
from matplotlib import gridspec
import matplotlib.pyplot as plt
fs = 10
matplotlib.rcParams['font.size']=fs
ms = 6
matplotlib.rcParams['lines.markersize']=ms



from astropy.cosmology import FlatLambdaCDM
cosmo = FlatLambdaCDM(H0=70., Om0=0.3)
z = 0.135
d_kpc = cosmo.luminosity_distance([z])[0].value * 1e+3
d_cm = d_kpc * 1e+3 * const.pc.cgs.value
scale = 4 * np.pi * d_cm**2 
scale1 = scale* 1.6e-9

# %%
def get_spectrum(num = 1, filename = "../data/Xray_yao_reduction/BestFit.qdp"):
    f = open(filename)
    lines = f.readlines()
    f.close()

    lines = lines[3:]
    sps = []
    count = 0
    for j in range(len(lines)):
        x =  lines[j]
        if x[:11] == 'NO NO NO NO':
            count +=1
            if count==num:
                break
            else:
                sps = []
        else:
            sps.append(x)
    return asci.read(sps)


def get_xray_nufnu(num = 1, filename="../data/Xray_yao_reduction/BestFit.qdp", ycol = None, 
                   fnu_unc_max = None, fnu_min = None):
    sp5 = get_spectrum(num = num, filename=filename)
    E = sp5["col1"] # keV
    nu = E * 1.6e-9 / const.h.cgs.value # Hz
    if ycol is None:
        E_unc = sp5["col2"] 
        nu_unc = E_unc * 1.6e-9 / const.h.cgs.value
        EfE = sp5["col3"] # keV^2 photon / cm^2 / s / keV
        EfE_unc = sp5["col4"]
        nufnu = EfE * 1.6e-9 # Hz erg / cm^2 / s / Hz
        nufnu_unc = EfE_unc * 1.6e-9
        fnu = nufnu / nu
        fnu_unc = nufnu_unc / nu
        tb = Table(data = [E, E_unc, EfE, EfE_unc, nu, nu_unc, fnu, fnu_unc, nufnu, nufnu_unc], 
                   names = ["E", "E_unc", "EfE", "EfE_unc",
                            "nu", "nu_unc", "fnu", "fnu_unc", "nufnu", "nufnu_unc"])
        if fnu_unc_max is not None:
            ix = tb["fnu_unc"] < fnu_unc_max
            tb = tb[ix]
    else:
        EfE = sp5[ycol] # keV^2 photon / cm^2 / s / keV
        nufnu = EfE * 1.6e-9 # Hz erg / cm^2 / s / Hz
        fnu = nufnu / nu
        tb = Table(data = [nu, fnu, E, EfE], names = ["nu", "fnu", "E", "EfE"])
    if fnu_min is not None:
        ix = tb["fnu"] > fnu_min
        tb = tb[ix]
    tb = tb.to_pandas()
    return tb

# %%
    color1 = "tab:green"
    color3 = "tab:brown"
    
    xfile1 = "../data/data_20mrf/srg/pavel_grped/ftgrouppha/eeufspec_delchi_1.qdp"
    df1 = get_xray_nufnu(num = 1, filename=xfile1) 
    err1 = get_spectrum(num = 2, filename=xfile1) 
    
    xfile3 = "../data/data_20mrf/srg/pavel_grped/ftgrouppha/eeufspec_delchi_3.qdp"
    df3 = get_xray_nufnu(num = 1, filename=xfile3) 
    err3 = get_spectrum(num = 2, filename=xfile3) 
    
    
    xfile1 = "../data/data_20mrf/srg/pavel_grped/ftgrouppha/eemodel_1.qdp"
    df_mod = get_xray_nufnu(num = 1, filename=xfile1, ycol = "col3")
    df_mod = df_mod[df_mod.E<12]
    df_mod1 = df_mod[df_mod.E>0.1]
    
    xfile3 = "../data/data_20mrf/srg/pavel_grped/ftgrouppha/eemodel_3.qdp"
    df_mod = get_xray_nufnu(num = 1, filename=xfile3, ycol = "col3")
    df_mod = df_mod[df_mod.E<12]
    df_mod3 = df_mod[df_mod.E>0.1]
    
    
    fig = plt.figure(figsize = (4.8, 3.6))
    gs = gridspec.GridSpec(2, 1, height_ratios=[2.5, 1]) 
    ax = plt.subplot(gs[0])
    

    ax.errorbar(df1["E"], df1["EfE"], df1["EfE_unc"], xerr = df1["E_unc"], fmt = "o", 
                color = "k", label = "eROSITA",  markersize = ms-2, linewidth = 0.8)
    ax.plot(df_mod1["E"], df_mod1["EfE"], linestyle = "--", color = color1, label = "powerlaw")
    ax.plot(df_mod3["E"], df_mod3["EfE"], linestyle = ":", color = color3, label = "apec")
    
    ax.legend()
    ax.semilogx()
    ax.semilogy()
    ax.set_ylabel(r"$E F_E$"+" ("+r"$\rm keV^2\, cm^{-2}\, s^{-1}\, keV^{-1}$"+")")
    
    ylim = ax.get_ylim()
    ymax = 3e-4
    ymin = 2e-6
    ylim = (ymin, ymax)
    yticklabels = ax.get_yticklabels()
    
    ax.set_ylim(ylim[0], ylim[1])
    ax.set_xticklabels([])
    
    ax2 = plt.subplot(gs[1])
    ax2.semilogx()
    xmin = 0.25
    xmax = 11
    ax.set_xlim(xmin, xmax)
    ax2.set_xlim(xmin, xmax)
    ax2.errorbar(err1["col1"], err1["col3"], xerr=err1["col2"], yerr=err1["col4"], 
                 fmt = "o", color = "k", markersize = ms-2, linewidth = 0.8)
    ax2.set_xlabel(r"$E$"+" (keV)")
    ax2.set_ylabel(r"$\chi$")
    ax2.yaxis.set_major_locator(plt.MultipleLocator(3))
    ax2.yaxis.set_minor_locator(plt.MultipleLocator(1))
    
    ax2.tick_params(which = 'major', length = 4, top=True, right=True, direction = "in")
    ax2.tick_params(which = 'minor', length = 2, top=True, right=True, direction = "in")
    ax.tick_params(which = 'major', length = 4, top=True, right=True, direction = "in")
    ax.tick_params(which = 'minor', length = 2, top=True, right=True, direction = "in")
    
    ax2.axhline(0, color='grey', linestyle = "-", alpha = 0.3)
    ax2.set_ylim(-3, 3.2)
    
    plt.tight_layout(h_pad = -0.05, rect =(-0.03, -0.05, 1.02, 1.02))
